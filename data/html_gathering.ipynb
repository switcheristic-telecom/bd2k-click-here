# %%
# this script gathers HTML files using the singlefile docker through subprocess. 
# first, define the language to be processed
LANGUAGE_TO_PROCESS = "ja"
import subprocess
import os
import json

# %%
# read the JSON file of the language to be processed
urls_to_download = []
json_data = []

with open(f"mhtml_results_{LANGUAGE_TO_PROCESS}.json", "r") as f:
    json_data = json.load(f)

if LANGUAGE_TO_PROCESS == "en" or LANGUAGE_TO_PROCESS == "zh": 
    for item in json_data: 
        timestamp = item['timestamp']
        original_url = item['url']
        item_url = "https://web.archive.org/web/{timestamp}if_/{original_url}".format(timestamp=timestamp, original_url=original_url)
        urls_to_download.append({
            "banner_md5": item["md5"],
            "url": item_url}
            )
elif LANGUAGE_TO_PROCESS == "es" or "ja":
    for item in json_data: 
        mhtml_file = item['mhtml_file']
        # open the mhtml file and read the Snapshot-Content-Location
        snapshot_content_location = ""
        with open(mhtml_file, "r") as f:
            content = f.read()
            snapshot_content_location = content.split("Snapshot-Content-Location: ")[1].split("\n")[0]
        # only append if banner_md5 is not already in the list
        if not any(d['banner_md5'] == item["banner_md5"] for d in urls_to_download):
            urls_to_download.append({
                'banner_md5': item["banner_md5"],
                'url': snapshot_content_location}
                )
else:
    print("Language not supported.")
    exit()

# %%
urls_to_download[10]
# Out:
# {'banner_md5': 'ba70f5e290b019a2f488b11ff4a99375',
#  'url': 'https://web.archive.org/web/19991010150746if_/http://www.japan-net.ne.jp/%7Ekakou/idolsearch/'}

# %%
# podman command: podman run singlefile "{url}" > {banner_md5}.html

# check how many files are there already downloaded in the directory
download_directory = f"html_{LANGUAGE_TO_PROCESS}"
# get a list of .html files in the directory
html_files = [f for f in os.listdir(download_directory) if f.endswith('.html')]
downloaded_md5s = [f.split(".html")[0] for f in html_files]

md5s_to_download = [item['banner_md5'] for item in urls_to_download if item['banner_md5'] not in downloaded_md5s]
# shuffle the list
import random
random.shuffle(md5s_to_download)

# download the files
for item in urls_to_download:
    if item['banner_md5'] in md5s_to_download:
        url = item['url']
        banner_md5 = item['banner_md5']
        print(f"Downloading {url}")
        command = f"podman run singlefile {url} > {download_directory}/{banner_md5}.html"
        subprocess.run(command, shell=True)
        print(f"Downloaded {url}")
# Out:
# Downloading https://web.archive.org/web/20020925193312if_/http://toushin.com/
# Downloaded https://web.archive.org/web/20020925193312if_/http://toushin.com/
# Downloading https://web.archive.org/web/20000620085552if_/http://www.vector.co.jp/
# Downloaded https://web.archive.org/web/20000620085552if_/http://www.vector.co.jp/
# Downloading https://web.archive.org/web/20000510191201if_/http://www.asahi.com/
# Downloaded https://web.archive.org/web/20000510191201if_/http://www.asahi.com/
# Downloading https://web.archive.org/web/20000510214314if_/http://www.asahi.com/
# Downloaded https://web.archive.org/web/20000510214314if_/http://www.asahi.com/
# Downloading https://web.archive.org/web/20011028102307if_/http://www.asahi.com/
# Downloaded https://web.archive.org/web/20011028102307if_/http://www.asahi.com/
# Downloading https://web.archive.org/web/20000620103514if_/http://www.asahi.com/
# Downloaded https://web.archive.org/web/20000620103514if_/http://www.asahi.com/
# Downloading https://web.archive.org/web/19981206154636if_/http://biztech.nikkeibp.co.jp/
# Downloaded https://web.archive.org/web/19981206154636if_/http://biztech.nikkeibp.co.jp/
# Downloading https://web.archive.org/web/20000619200305if_/http://biztech.nikkeibp.co.jp/
# Downloaded https://web.archive.org/web/20000619200305if_/http://biztech.nikkeibp.co.jp/
# Downloading https://web.archive.org/web/20010609124758if_/http://biztech.nikkeibp.co.jp/
# Downloaded https://web.archive.org/web/20010609124758if_/http://biztech.nikkeibp.co.jp/
# Downloading https://web.archive.org/web/20010511014958if_/http://www.japan-net.ne.jp/~kakou/idolsearch/
# Unreachable URL: https://web.archive.org/web/20010511014958if_/http://www.japan-net.ne.jp/~kakou/idolsearch/ [2024-09-21T06:58:32.608Z] URL: https://web.archive.org/web/20010511014958if_/http://www.japan-net.ne.jp/~kakou/idolsearch/
# Downloaded https://web.archive.org/web/20010511014958if_/http://www.japan-net.ne.jp/~kakou/idolsearch/
# Downloading https://web.archive.org/web/19991010150746if_/http://www.japan-net.ne.jp/%7Ekakou/idolsearch/
# Downloaded https://web.archive.org/web/19991010150746if_/http://www.japan-net.ne.jp/%7Ekakou/idolsearch/
# Downloading https://web.archive.org/web/20021201130903if_/http://home.gol.com/
# Downloaded https://web.archive.org/web/20021201130903if_/http://home.gol.com/
# Downloading https://web.archive.org/web/20010405191057if_/http://softplaza.biglobe.ne.jp/index.html
# Downloaded https://web.archive.org/web/20010405191057if_/http://softplaza.biglobe.ne.jp/index.html
# Downloading https://web.archive.org/web/20021012040911if_/http://softplaza.biglobe.ne.jp/index.html
# Downloaded https://web.archive.org/web/20021012040911if_/http://softplaza.biglobe.ne.jp/index.html
# Downloading https://web.archive.org/web/20020620095024if_/http://www.geocities.co.jp/Technopolis/2515/
# Unreachable URL: https://web.archive.org/web/20020620095024if_/http://www.geocities.co.jp/Technopolis/2515/ [2024-09-21T06:59:19.711Z] URL: https://web.archive.org/web/20020620095024if_/http://www.geocities.co.jp/Technopolis/2515/
# Downloaded https://web.archive.org/web/20020620095024if_/http://www.geocities.co.jp/Technopolis/2515/
# Downloading https://web.archive.org/web/20020605135927if_/http://www.geocities.co.jp/SweetHome/1127/
# Downloaded https://web.archive.org/web/20020605135927if_/http://www.geocities.co.jp/SweetHome/1127/
# Downloading https://web.archive.org/web/20021107104211if_/http://www.unhcr.or.jp/
# Downloaded https://web.archive.org/web/20021107104211if_/http://www.unhcr.or.jp/
# Downloading https://web.archive.org/web/19991013225620if_/http://sports.yahoo.co.jp/horse
# Downloaded https://web.archive.org/web/19991013225620if_/http://sports.yahoo.co.jp/horse
# Downloading https://web.archive.org/web/19991127092956if_/http://www.kumagaya.or.jp/~mamada/deai/deai.htm
# Downloaded https://web.archive.org/web/19991127092956if_/http://www.kumagaya.or.jp/~mamada/deai/deai.htm
# Downloading https://web.archive.org/web/20000816204018if_/http://www.kumagaya.or.jp/~mamada/deai/deai.htm
# Downloaded https://web.archive.org/web/20000816204018if_/http://www.kumagaya.or.jp/~mamada/deai/deai.htm
# Downloading https://web.archive.org/web/20001109200700if_/http://www.kumagaya.or.jp/~mamada/deai/deai.htm
# Downloaded https://web.archive.org/web/20001109200700if_/http://www.kumagaya.or.jp/~mamada/deai/deai.htm
# Downloading https://web.archive.org/web/20001109200700if_/http://www.kumagaya.or.jp/~mamada/deai/deai.htm
# Downloaded https://web.archive.org/web/20001109200700if_/http://www.kumagaya.or.jp/~mamada/deai/deai.htm
# Downloading https://web.archive.org/web/20001007151853if_/http://www.kumagaya.or.jp/~mamada/deai/deai.htm
# Downloaded https://web.archive.org/web/20001007151853if_/http://www.kumagaya.or.jp/~mamada/deai/deai.htm
# Downloading https://web.archive.org/web/20000304110610if_/http://www.mahjong.or.jp/
# Unreachable URL: https://web.archive.org/web/20000304110610if_/http://www.mahjong.or.jp/ [2024-09-21T07:01:11.264Z] URL: https://web.archive.org/web/20000304110610if_/http://www.mahjong.or.jp/
# Downloaded https://web.archive.org/web/20000304110610if_/http://www.mahjong.or.jp/
# Downloading https://web.archive.org/web/20000304035837if_/http://netnavi.nikkeibp.co.jp/top/top.shtml
# Downloaded https://web.archive.org/web/20000304035837if_/http://netnavi.nikkeibp.co.jp/top/top.shtml
# Downloading https://web.archive.org/web/19980421221627if_/http://www.bloomberg.com/jp/jphome.html
# Unreachable URL: https://web.archive.org/web/19980421221627if_/http://www.bloomberg.com/jp/jphome.html [2024-09-21T07:01:28.351Z] URL: https://web.archive.org/web/19980421221627if_/http://www.bloomberg.com/jp/jphome.html
# Downloaded https://web.archive.org/web/19980421221627if_/http://www.bloomberg.com/jp/jphome.html
# Downloading https://web.archive.org/web/20000817083727if_/http://www.marunaka.com/straight/
# Downloaded https://web.archive.org/web/20000817083727if_/http://www.marunaka.com/straight/
# Downloading https://web.archive.org/web/20010201050100if_/http://www.oita-press.co.jp/
# Unreachable URL: https://web.archive.org/web/20010201050100if_/http://www.oita-press.co.jp/ [2024-09-21T07:01:49.475Z] URL: https://web.archive.org/web/20010201050100if_/http://www.oita-press.co.jp/
# Downloaded https://web.archive.org/web/20010201050100if_/http://www.oita-press.co.jp/
# Downloading https://web.archive.org/web/20020605165226if_/http://www2.117.ne.jp/~vision/paf/
# Downloaded https://web.archive.org/web/20020605165226if_/http://www2.117.ne.jp/~vision/paf/
# Downloading https://web.archive.org/web/19981205193950if_/http://ww6.tiki.ne.jp/%7Efresh-blow/
# Downloaded https://web.archive.org/web/19981205193950if_/http://ww6.tiki.ne.jp/%7Efresh-blow/
# Downloading https://web.archive.org/web/20010516034420if_/http://www.kyototool.co.jp/
# Downloaded https://web.archive.org/web/20010516034420if_/http://www.kyototool.co.jp/
# Downloading https://web.archive.org/web/20010924235746if_/http://www.kyototool.co.jp/
# Downloaded https://web.archive.org/web/20010924235746if_/http://www.kyototool.co.jp/
# Downloading https://web.archive.org/web/20000511020650if_/http://www.kyototool.co.jp/
# Downloaded https://web.archive.org/web/20000511020650if_/http://www.kyototool.co.jp/
# Downloading https://web.archive.org/web/20020605033313if_/http://www.fancyparts.com/denmama/
# Downloaded https://web.archive.org/web/20020605033313if_/http://www.fancyparts.com/denmama/
# Downloading https://web.archive.org/web/20011211175336if_/http://www.fancyparts.com/denmama/
# Downloaded https://web.archive.org/web/20011211175336if_/http://www.fancyparts.com/denmama/
# Downloading https://web.archive.org/web/20000621212628if_/http://yubitoma.sphere.ne.jp/
# Downloaded https://web.archive.org/web/20000621212628if_/http://yubitoma.sphere.ne.jp/
# Downloading https://web.archive.org/web/20010613052337if_/http://www.geocities.co.jp/Technopolis/1264/
# Downloaded https://web.archive.org/web/20010613052337if_/http://www.geocities.co.jp/Technopolis/1264/
# Downloading https://web.archive.org/web/20021216204253if_/http://www.geocities.co.jp/Technopolis/1264/
# Downloaded https://web.archive.org/web/20021216204253if_/http://www.geocities.co.jp/Technopolis/1264/
# Downloading https://web.archive.org/web/20021129172624if_/http://www.aruke.com/
# Downloaded https://web.archive.org/web/20021129172624if_/http://www.aruke.com/
# Downloading https://web.archive.org/web/20020602142152if_/http://www.miyagino.com/links/
# Downloaded https://web.archive.org/web/20020602142152if_/http://www.miyagino.com/links/
# Downloading https://web.archive.org/web/19991002182106if_/http://travel.mimo.com/camp/
# Downloaded https://web.archive.org/web/19991002182106if_/http://travel.mimo.com/camp/
# Downloading https://web.archive.org/web/20010711204349if_/http://weather.mainichi.co.jp/
# Downloaded https://web.archive.org/web/20010711204349if_/http://weather.mainichi.co.jp/
# Downloading https://web.archive.org/web/20011106211902if_/http://www.geocities.co.jp/SilkRoad/2819/
# Downloaded https://web.archive.org/web/20011106211902if_/http://www.geocities.co.jp/SilkRoad/2819/
# Downloading https://web.archive.org/web/20010302123913if_/http://www.rurubu.com/
# Downloaded https://web.archive.org/web/20010302123913if_/http://www.rurubu.com/
# Downloading https://web.archive.org/web/20000302151017if_/http://www.yadojozu.ne.jp/
# Downloaded https://web.archive.org/web/20000302151017if_/http://www.yadojozu.ne.jp/
# Downloading https://web.archive.org/web/20001017225828/http://www13.mainichi.co.jp/index.html
# Downloaded https://web.archive.org/web/20001017225828/http://www13.mainichi.co.jp/index.html
# Downloading https://web.archive.org/web/20010418144426if_/http://www.mainichi.co.jp/
# Downloaded https://web.archive.org/web/20010418144426if_/http://www.mainichi.co.jp/
# Downloading https://web.archive.org/web/20000407112542if_/http://www.shikoku-np.co.jp/
# Downloaded https://web.archive.org/web/20000407112542if_/http://www.shikoku-np.co.jp/
# Downloading https://web.archive.org/web/20021120221232if_/http://www.shikoku-np.co.jp/
# Downloaded https://web.archive.org/web/20021120221232if_/http://www.shikoku-np.co.jp/
# Downloading https://web.archive.org/web/20000819025208if_/http://www2n.biglobe.ne.jp/~b777-300/
# Downloaded https://web.archive.org/web/20000819025208if_/http://www2n.biglobe.ne.jp/~b777-300/
# Downloading https://web.archive.org/web/20010118202800if_/http://www.skinet.co.jp/
# Unreachable URL: https://web.archive.org/web/20010118202800if_/http://www.skinet.co.jp/ [2024-09-21T07:06:18.785Z] URL: https://web.archive.org/web/20010118202800if_/http://www.skinet.co.jp/
# Downloaded https://web.archive.org/web/20010118202800if_/http://www.skinet.co.jp/
# Downloading https://web.archive.org/web/20010604075334if_/http://netnavi.nikkeibp.co.jp/top/provider/top.shtml
# Unreachable URL: https://web.archive.org/web/20010604075334if_/http://netnavi.nikkeibp.co.jp/top/provider/top.shtml [2024-09-21T07:06:20.065Z] URL: https://web.archive.org/web/20010604075334if_/http://netnavi.nikkeibp.co.jp/top/provider/top.shtml
# Downloaded https://web.archive.org/web/20010604075334if_/http://netnavi.nikkeibp.co.jp/top/provider/top.shtml
# Downloading https://web.archive.org/web/20010812035826if_/http://netnavi.nikkeibp.co.jp/top/provider/top.shtml
# Downloaded https://web.archive.org/web/20010812035826if_/http://netnavi.nikkeibp.co.jp/top/provider/top.shtml
# Downloading https://web.archive.org/web/20011204171713if_/http://www.faxpress.co.jp/Snow/
# Downloaded https://web.archive.org/web/20011204171713if_/http://www.faxpress.co.jp/Snow/
# Downloading https://web.archive.org/web/19991007122621if_/http://www.smartfinance.net/
# Downloaded https://web.archive.org/web/19991007122621if_/http://www.smartfinance.net/
# Downloading https://web.archive.org/web/20000706205200if_/http://www.moneyjoho.co.jp/
# Downloaded https://web.archive.org/web/20000706205200if_/http://www.moneyjoho.co.jp/
# Downloading https://web.archive.org/web/20001015203255if_/http://map.yahoo.co.jp/
# Downloaded https://web.archive.org/web/20001015203255if_/http://map.yahoo.co.jp/
# Downloading https://web.archive.org/web/20001019035001if_/http://map.yahoo.co.jp/
# Downloaded https://web.archive.org/web/20001019035001if_/http://map.yahoo.co.jp/
# Downloading https://web.archive.org/web/20000815200622if_/http://www.kau.com/pcprice/
# Downloaded https://web.archive.org/web/20000815200622if_/http://www.kau.com/pcprice/
# Downloading https://web.archive.org/web/20000510084220if_/http://www.morningstar.co.jp/
# Unreachable URL: https://web.archive.org/web/20000510084220if_/http://www.morningstar.co.jp/ [2024-09-21T07:07:42.878Z] URL: https://web.archive.org/web/20000510084220if_/http://www.morningstar.co.jp/
# Downloaded https://web.archive.org/web/20000510084220if_/http://www.morningstar.co.jp/
# Downloading https://web.archive.org/web/20010119180900if_/http://www.forest.impress.co.jp/
# Downloaded https://web.archive.org/web/20010119180900if_/http://www.forest.impress.co.jp/
# Downloading https://web.archive.org/web/20010509092400if_/http://transit.yahoo.co.jp/
# Downloaded https://web.archive.org/web/20010509092400if_/http://transit.yahoo.co.jp/
# Downloading https://web.archive.org/web/20001007135007if_/http://weapon.org/
# Downloaded https://web.archive.org/web/20001007135007if_/http://weapon.org/
# Downloading https://web.archive.org/web/20020103065241if_/http://www2.baywell.ne.jp/NEWSINDEX/
# Downloaded https://web.archive.org/web/20020103065241if_/http://www2.baywell.ne.jp/NEWSINDEX/
# Downloading https://web.archive.org/web/19981111184307if_/http://www.nikkei.co.jp/
# Downloaded https://web.archive.org/web/19981111184307if_/http://www.nikkei.co.jp/
# Downloading https://web.archive.org/web/20000706231057if_/http://www.nikkei.co.jp/
# Downloaded https://web.archive.org/web/20000706231057if_/http://www.nikkei.co.jp/
# Downloading https://web.archive.org/web/20010118202100if_/http://www.nikkei.co.jp/
# Downloaded https://web.archive.org/web/20010118202100if_/http://www.nikkei.co.jp/
# Downloading https://web.archive.org/web/20010531190430if_/http://www.geocities.co.jp/Milkyway/3760/
# Downloaded https://web.archive.org/web/20010531190430if_/http://www.geocities.co.jp/Milkyway/3760/
# Downloading https://web.archive.org/web/20000707010331if_/http://mbs.co.jp/
# Downloaded https://web.archive.org/web/20000707010331if_/http://mbs.co.jp/
# Downloading https://web.archive.org/web/20000823091241if_/http://www2.justnet.ne.jp/~vcarp/idol/
# Downloaded https://web.archive.org/web/20000823091241if_/http://www2.justnet.ne.jp/~vcarp/idol/
# Downloading https://web.archive.org/web/20021202215627if_/http://village.infoweb.ne.jp/~fwhp1575/index.htm
# Downloaded https://web.archive.org/web/20021202215627if_/http://village.infoweb.ne.jp/~fwhp1575/index.htm
# Downloading https://web.archive.org/web/19981205141956if_/http://www.tokyoin.com/search.htm
# Downloaded https://web.archive.org/web/19981205141956if_/http://www.tokyoin.com/search.htm
# Downloading https://web.archive.org/web/20000817074340if_/http://www.geocities.co.jp/HeartLand/3764/
# Downloaded https://web.archive.org/web/20000817074340if_/http://www.geocities.co.jp/HeartLand/3764/
# Downloading https://web.archive.org/web/20010619052510if_/http://www.hokkaido-np.co.jp/
# Downloaded https://web.archive.org/web/20010619052510if_/http://www.hokkaido-np.co.jp/
# Downloading https://web.archive.org/web/19980125063314if_/http://www.benri.com/
# Downloaded https://web.archive.org/web/19980125063314if_/http://www.benri.com/
# Downloading https://web.archive.org/web/20010402053946if_/http://www.alico.co.jp/
# Downloaded https://web.archive.org/web/20010402053946if_/http://www.alico.co.jp/
# Downloading https://web.archive.org/web/19991110032454if_/http://www.mainichi.co.jp/suponichi/index.html
# Downloaded https://web.archive.org/web/19991110032454if_/http://www.mainichi.co.jp/suponichi/index.html
# Downloading https://web.archive.org/web/20000510152810if_/http://www.mainichi.co.jp/suponichi/index.html
# Downloaded https://web.archive.org/web/20000510152810if_/http://www.mainichi.co.jp/suponichi/index.html
# Downloading https://web.archive.org/web/20000619024257if_/http://www.mainichi.co.jp/suponichi/index.html
# Downloaded https://web.archive.org/web/20000619024257if_/http://www.mainichi.co.jp/suponichi/index.html
# Downloading https://web.archive.org/web/20010130094100if_/http://www.mainichi.co.jp/suponichi/index.html
# Downloaded https://web.archive.org/web/20010130094100if_/http://www.mainichi.co.jp/suponichi/index.html
# Downloading https://web.archive.org/web/20000607212625if_/http://www.geocities.co.jp/Technopolis/2888/index.html
# Downloaded https://web.archive.org/web/20000607212625if_/http://www.geocities.co.jp/Technopolis/2888/index.html
# Downloading https://web.archive.org/web/20000304151818if_/http://netnavi.nikkeibp.co.jp/top/event/schedule.shtml
# Downloaded https://web.archive.org/web/20000304151818if_/http://netnavi.nikkeibp.co.jp/top/event/schedule.shtml
# Downloading https://web.archive.org/web/20020210160903if_/http://www.geocities.co.jp/HeartLand-Namiki/8810/index.html
# Downloaded https://web.archive.org/web/20020210160903if_/http://www.geocities.co.jp/HeartLand-Namiki/8810/index.html
# Downloading https://web.archive.org/web/20020523143759if_/http://wan.ne.jp/
# Downloaded https://web.archive.org/web/20020523143759if_/http://wan.ne.jp/
# Downloading https://web.archive.org/web/20010124145900if_/http://www.office-k.com/tin/
# Downloaded https://web.archive.org/web/20010124145900if_/http://www.office-k.com/tin/
# Downloading https://web.archive.org/web/20020123010721if_/http://www.diyer.com/
# Downloaded https://web.archive.org/web/20020123010721if_/http://www.diyer.com/
# Downloading https://web.archive.org/web/20001202032200if_/http://netnavi.nikkeibp.co.jp/top/search/top.shtml
# Downloaded https://web.archive.org/web/20001202032200if_/http://netnavi.nikkeibp.co.jp/top/search/top.shtml
# Downloading https://web.archive.org/web/20021013054730if_/http://www.kbnet.jp.org/11pm/kyokai/
# Downloaded https://web.archive.org/web/20021013054730if_/http://www.kbnet.jp.org/11pm/kyokai/
# Downloading https://web.archive.org/web/19990422112807if_/http://www.daikyo.co.jp/
# Downloaded https://web.archive.org/web/19990422112807if_/http://www.daikyo.co.jp/
# Downloading https://web.archive.org/web/20010301211110if_/http://www.mapoo.or.jp/
# Downloaded https://web.archive.org/web/20010301211110if_/http://www.mapoo.or.jp/
# Downloading https://web.archive.org/web/20000621192322if_/http://www.zdnet.co.jp/
# Downloaded https://web.archive.org/web/20000621192322if_/http://www.zdnet.co.jp/
# Downloading https://web.archive.org/web/20020124034325if_/http://www.zdnet.co.jp/
# Downloaded https://web.archive.org/web/20020124034325if_/http://www.zdnet.co.jp/
# Downloading https://web.archive.org/web/20021017072851if_/http://www.geocities.co.jp/HeartLand/3510/
# Downloaded https://web.archive.org/web/20021017072851if_/http://www.geocities.co.jp/HeartLand/3510/
# Downloading https://web.archive.org/web/20000901032556if_/http://www.geocities.co.jp/Technopolis/2574/
# Downloaded https://web.archive.org/web/20000901032556if_/http://www.geocities.co.jp/Technopolis/2574/
# Downloading https://web.archive.org/web/20000304094013if_/http://www.koubo.co.jp/
# Downloaded https://web.archive.org/web/20000304094013if_/http://www.koubo.co.jp/
# Downloading https://web.archive.org/web/19991012022502if_/http://netplaza.biglobe.ne.jp/
# Downloaded https://web.archive.org/web/19991012022502if_/http://netplaza.biglobe.ne.jp/
# Downloading https://web.archive.org/web/20001121115100if_/http://netplaza.biglobe.ne.jp/
# Downloaded https://web.archive.org/web/20001121115100if_/http://netplaza.biglobe.ne.jp/
